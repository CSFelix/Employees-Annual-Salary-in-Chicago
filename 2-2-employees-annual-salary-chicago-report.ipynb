# %% [markdown]
# <h1 align="center" style="color:blue">🧑‍💼 Analysis Report: Employees' Annual Salary in Chicago 🧑‍💼</h1>
#
# <p>Howdy 👋👋, in this notebook I made the report of the Exploratory Analysis of my dataset
#     <a href="https://www.kaggle.com/datasets/dsfelix/employees-annual-salary-in-chicago">Employees' Annual Salary in Chicago</a>.</p>
#
# <p>My goal in this post is just summarize all the results I got in the first dataset: <a href="https://www.kaggle.com/code/dsfelix/1-2-employees-annual-salary-in-chicago-analysis">1/2 - Employees' Annual Salary in Chicago Analysis</a></p>
#
# <p>I'm still a newbie in Data Science and I know that there are a huge other things that I can do in Exploratory Analysis, but I think this a good starter hehehe.</p>
#
# <p>Share your thoughts about the notebook and the dataset, such as ways to improve, tips and other cool things I could be doing in the Analisis. It'll be so helpfull 😀😀</p>
#
# To make the report easier, let's split it into two sections: `Monthly/Salary Employees` and `Hourly Employees`. Well, let's go!

# %% [markdown]
# <h1 style="color:blue">0) Monthly/Salary Employees</h1>

# %% [markdown]
# <b>Five Most Paid Employees</b>
#
# <br><br>
#
# <table>
#     <tr>
#         <th>Name</th>
#         <th>Job Title</th>
#         <th>Department</th>
#         <th>Full or Part-Time</th>
#         <th>Annual Salary - Dollars</th>
#         <th>Monthly Salary - Dollars</th>
#     </tr>
#     <tr>
#         <td>RHEE,  JAMIE L</td>
#         <td>COMMISSIONER OF AVIATION</td>
#         <td>AVIATION</td>
#         <td>Full-Time</td>
#         <td>275,004.00</td>
#         <td>22,917.00</td>
#     </tr>
#     <tr>
#         <td>BROWN,  DAVID O</td>
#         <td>SUPERINTENDENT OF POLICE</td>
#         <td>POLICE</td>
#         <td>Full-Time</td>
#         <td>260,004.00</td>
#         <td>21,667.00</td>
#     </tr>
#     <tr>
#         <td>NANCE HOLT,  ANNETTE M</td>
#         <td>FIRE COMMISSIONER</td>
#         <td>FIRE</td>
#         <td>Full-Time</td>
#         <td>228,612.00</td>
#         <td>19,051.00</td>
#     </tr>
#     <tr>
#         <td>LIGHTFOOT,  LORI E</td>
#         <td>MAYOR</td>
#         <td>MAYOR'S OFFICE</td>
#         <td>Full-Time</td>
#         <td>216,210.00</td>
#         <td>18,017.50</td>
#     </tr>
#     <tr>
#         <td>SHERIDAN,  MARY L</td>
#         <td>FIRST DEPUTY FIRE COMMISSIONER</td>
#         <td>FIRE</td>
#         <td>Full-Time</td>
#         <td>207,624.00</td>
#         <td>17,302.00</td>
#     </tr>
# </table>

# %% [markdown]
# ----
#
# <b>Five Less Paid Employees</b>
#
# <br><br>
#
# <table>
#     <tr>
#         <th>Name</th>
#         <th>Job Title</th>
#         <th>Department</th>
#         <th>Full or Part-Time</th>
#         <th>Annual Salary - Dollars</th>
#         <th>Monthly Salary - Dollars</th>
#     </tr>
#     <tr>
#         <td>ADELMAN,  BRUCE E</td>
#         <td>LEGISLATIVE AIDE</td>
#         <td>CITY COUNCIL</td>
#         <td>Full-Time</td>
#         <td>21,600.00</td>
#         <td>1,800.00</td>
#     </tr>
#     <tr>
#         <td>BURKS,  BRITTANY S</td>
#         <td>ALDERMANIC AIDE</td>
#         <td>CITY COUNCIL</td>
#         <td>Full-Time</td>
#         <td>23,208.00</td>
#         <td>1,934.00</td>
#     </tr>
#     <tr>
#         <td>MARTIN,  CAROLINE J</td>
#         <td>ALDERMANIC AIDE</td>
#         <td>CITY COUNCIL</td>
#         <td>Full-Time</td>
#         <td>30,000.00</td>
#         <td>2,500.00</td>
#     </tr>
#     <tr>
#         <td>TOMPKINS,  ANGELA A</td>
#         <td>CLERK - BD OF ELECTIONS</td>
#         <td>BOARD OF ELECTION</td>
#         <td>Full-Time</td>
#         <td>30,060.00/td>
#         <td>2,505.00</td>
#     </tr>
#     <tr>
#         <td>WILSON,  KAHLIL M</td>
#         <td>CLERK - BD OF ELECTIONS</td>
#         <td>BOARD OF ELECTION</td>
#         <td>Full-Time</td>
#         <td>30,060.00</td>
#         <td>2,505.00</td>
#     </tr>
# </table>

# %% [markdown]
# ----
#
# <b>Five Most Paid Job Titles (avg)</b>
#
# <br><br>
#
# <table>
#     <tr>
#         <th>Job Title</th>
#         <th>Annual Salary - Dollars (avg)</th>
#     </tr>
#     <tr>
#         <td>COMMISSIONER OF AVIATION</td>
#         <td>275,004.00</td>
#     </tr>
#     <tr>
#         <td>SUPERINTENDENT OF POLICE</td>
#         <td>260,004.00</td>
#     </tr>
#     <tr>
#         <td>FIRE COMMISSIONER</td>
#         <td>228,612.00</td>
#     </tr>
#     <tr>
#         <td>MAYOR</td>
#         <td>216,210.00</td>
#     </tr>
#     <tr>
#         <td>FIRST DEPUTY FIRE COMMISSIONER</td>
#         <td>207,624.00</td>
#     </tr>
# </table>

# %% [markdown]
# ----
#
# <b>Five Less Paid Job Titles (avg)</b>
#
# <br><br>
#
# <table>
#     <tr>
#         <th>Job Title</th>
#         <th>Annual Salary - Dollars (avg)</th>
#     </tr>
#     <tr>
#         <td>TRAFFIC ENFORCEMENT TECH</td>
#         <td>39,581.45</td>
#     </tr>
#     <tr>
#         <td>REPROGRAPHICS TECHNICIAN II</td>
#         <td>37,224.00</td>
#     </tr>
#     <tr>
#         <td>COMMITTEE SECRETARY</td>
#         <td>34,476.00</td>
#     </tr>
#     <tr>
#         <td>CLERK - BD OF ELECTIONS</td>
#         <td>34,384.62</td>
#     </tr>
#     <tr>
#         <td>ELECTION EQUIPMENT & SUPPLY SPEC I</td>
#         <td>32,460.00</td>
#     </tr>
# </table>

# %% [markdown]
# ----
#
# <b>Average Monthly Salary (3 Most Paid and 3 Less Paid)</b>
#
# <br><br>
#
# <table>
#     <tr>
#         <th>Job Title</th>
#         <th>Annual Salary - Dollars (avg)</th>
#     </tr>
#     <tr>
#         <td>COMMISSIONER OF AVIATION</td>
#         <td>22,917.00</td>
#     </tr>
#     <tr>
#         <td>SUPERINTENDENT OF POLICE</td>
#         <td>21,667.00</td>
#     </tr>
#     <tr>
#         <td>FIRE COMMISSIONER</td>
#         <td>19,051.00</td>
#     </tr>
#     <tr>
#         <td>[...]</td>
#         <td>[...]</td>
#     </tr>
#     <tr>
#         <td>COMMITTEE SECRETARY</td>
#         <td>2,873.00</td>
#     </tr>
#     <tr>
#         <td>CLERK - BD OF ELECTIONS</td>
#         <td>2,865.38</td>
#     </tr>
#     <tr>
#         <td>ELECTION EQUIPMENT & SUPPLY SPEC I</td>
#         <td>2,705.00</td>
#     </tr>
# </table>

# %% [markdown]
# ----
#
# <b>Correlation Plot</b>

# %%
from IPython.display import Image
Image("../input/employees-annual-salary-in-chicago/Monthly Salary - Correlation Plot.png")

# %% [markdown]
# * Job Titles column has a considerable influence to the Annual Salary;
#
# * Department column has a tiny influence;
#
# * And Full or Part-Time columns doesn't have any influence.

# %% [markdown]
# ----
#
# <b>Relationship between the Variables</b>

# %%
# Annual Salary X Job Titles
Image("../input/employees-annual-salary-in-chicago/Annual Salary X Job Titles.png")

# %% [markdown]
# <p>We can assume that the AVG Annual Salary is around <b>U$ 100,000.00</b> and the Monthly Salary is around <b>8,333.33 dollars</b>.</p>

# %%
# Annual Salary X Department
Image("../input/employees-annual-salary-in-chicago/Annual Salary X Department.png")

# %% [markdown]
# <p>We have employeees worrking at the same department but with different salary values. It happen due to numerous reasons, such as experience time, promotions and education degree.</p>

# %% [markdown]
# ----
#
# <h1 style="color: blue">1) Hourly Employees</h1>

# %% [markdown]
# <b>Five Most Paid Employees</b>
#
# <br><br>
#
# <table>
#     <tr>
#         <th>Name</th>
#         <th>Job Title</th>
#         <th>Department</th>
#         <th>Full or Part-Time</th>
#         <th>Typical Hours</th>
#         <th>Hourly Rate - Dollars</th>
#     </tr>
#     <tr>
#         <td>RAO,  ANITA</td>
#         <td>PSYCHIATRIST</td>
#         <td>HEALTH</td>
#         <td>Full-Time</td>
#         <td>35.0 hours</td>
#         <td>134.40</td>
#     </tr>
#     <tr>
#         <td>JONES,  JOHN W</td>
#         <td>PSYCHIATRIST</td>
#         <td>HEALTH</td>
#         <td>Full-Time</td>
#         <td>35.0 hours</td>
#         <td>134.40</td>
#     </tr>
#     <tr>
#         <td>RUFFIN,  LARITA A</td>
#         <td>PARKING ENFORCEMENT AIDE</td>
#         <td>FINANCE</td>
#         <td>Full-Time</td>
#         <td>20.0 hours</td>
#         <td>128.97</td>
#     </tr>
#     <tr>
#         <td>JILEK,  GEORGE J</td>
#         <td>DENTIST</td>
#         <td>HEALTH</td>
#         <td>Full-Time</td>
#         <td>35.0 hours</td>
#         <td>64.30</td>
#     </tr>
#     <tr>
#         <td>HUGHES,  THOMAS J</td>
#         <td>FOREMAN OF LINEMEN</td>
#         <td>TRANSPORTN</td>
#         <td>Full-Time</td>
#         <td>40.0 hours</td>
#         <td>62.05</td>
#     </tr>
# </table>

# %% [markdown]
# ----
#
# <b>Five Less Paid Employees</b>
#
# <br><br>
#
# <table>
#     <tr>
#         <th>Name</th>
#         <th>Job Title</th>
#         <th>Department</th>
#         <th>Full or Part-Time</th>
#         <th>Typical Hours</th>
#         <th>Hourly Rate - Dollars</th>
#     </tr>
#     <tr>
#         <td>FELKER,  CAROLYN</td>
#         <td>SENIOR COMPANION</td>
#         <td>FAMILY & SUPPORT</td>
#         <td>Part-Time</td>
#         <td>20.0 hours</td>
#         <td>3.00</td>
#     </tr>
#     <tr>
#         <td>GAILES,  RITA</td>
#         <td>FOSTER GRANDPARENT</td>
#         <td>FAMILY & SUPPORT</td>
#         <td>Part-Time</td>
#         <td>20.0 hours</td>
#         <td>3.00</td>
#     </tr>
#     <tr>
#         <td>WILLIAMS,  BRENDA</td>
#         <td>FOSTER GRANDPARENT</td>
#         <td>FAMILY & SUPPORT</td>
#         <td>Part-Time</td>
#         <td>20.0 hours</td>
#         <td>3.00</td>
#     </tr>
#     <tr>
#         <td>MCGEE,  ARIE</td>
#         <td>SENIOR COMPANION</td>
#         <td>FAMILY & SUPPORT</td>
#         <td>Part-Time</td>
#         <td>20.0 hours</td>
#         <td>3.00</td>
#     </tr>
#     <tr>
#         <td>STEWART,  BARBARA</td>
#         <td>SENIOR COMPANION</td>
#         <td>FAMILY & SUPPORT</td>
#         <td>Part-Time</td>
#         <td>20.0 hours</td>
#         <td>3.00</td>
#     </tr>
# </table>

# %% [markdown]
# ----
#
# <b>Five Most Paid Job Titles (avg)</b>
#
# <br><br>
#
# <table>
#     <tr>
#         <th>Job Title</th>
#         <th>Hourly Rate - Dollars (avg)</th>
#     </tr>
#     <tr>
#         <td>PSYCHIATRIST</td>
#         <td>134.40</td>
#     </tr>
#     <tr>
#         <td>PARKING ENFORCEMENT AIDE</td>
#         <td>128.97</td>
#     </tr>
#     <tr>
#         <td>DENTIST</td>
#         <td>64.30</td>
#     </tr>
#     <tr>
#         <td>FOREMAN OF LINEMEN</td>
#         <td>62.05</td>
#     </tr>
#     <tr>
#         <td>ASST CORPORATION COUNSEL III</td>
#         <td>59.47</td>
#     </tr>
# </table>

# %% [markdown]
# ----
#
# <b>Five Less Paid Job Titles (avg)</b>
#
# <br><br>
#
# <table>
#     <tr>
#         <th>Job Title</th>
#         <th>Hourly Rate - Dollars (avg)</th>
#     </tr>
#     <tr>
#         <td>HOSPITALITY WORKER</td>
#         <td>15.00</td>
#     </tr>
#     <tr>
#         <td>LIBRARY PAGE</td>
#         <td>15.00</td>
#     </tr>
#     <tr>
#         <td>LAW CLERK</td>
#         <td>15.00</td>
#     </tr>
#     <tr>
#         <td>FOSTER GRANDPARENT</td>
#         <td>3.00</td>
#     </tr>
#     <tr>
#         <td>SENIOR COMPANION</td>
#         <td>3.00</td>
#     </tr>
# </table>

# %% [markdown]
# ----
#
# <b>Correlation Plot</b>

# %%
from IPython.display import Image
Image("../input/employees-annual-salary-in-chicago/Hourly Salary - Correlation Plot.png")

# %% [markdown]
# * Job Titles column has a considerable influence to the Hourly Rate;
#
# * Department column has a tiny influence;
#
# * Full or Part-Time columns doesn't have any influence;
#
# * Typical Hours column has a considerable influence to the Hourly Rate, but less than the Job Titles one.

# %% [markdown]
# ----
#
# <b>Relationship between the Variables</b>

# %%
# Hourly Rate X Job Titles
Image("../input/employees-annual-salary-in-chicago/Hourly Rate X Job Title.png")

# %% [markdown]
# <p>We can assume that the AVG Hourly Rate is around <b>U$ 40.00</b>.</p>

# %%
# Hourly Rate X Department
Image("../input/employees-annual-salary-in-chicago/Hourly Rate X Department.png")

# %% [markdown]
# <p>We have employeees worrking at the same department but with different salary values. It happen due to numerous reasons, such as experience time, promotions and education degree.</p>

# %%
# Hourly Rate X Typical Hours
Image("../input/employees-annual-salary-in-chicago/Hourly Rate X Typical Hours.png")

# %% [markdown]
# <p>We can assume the most employeees work <b>40 hours</b> per week.</p>

# %% [markdown]
# ----
#
# <h1 style="color: blue">2) Wrapping Up</h1>
#
# Well, one more notebook has been wrapped up. When I get a good level of understanding and practice with Machine Learning, I will come back with this dataset in a new notebook where I will be creating two Machine Learning Models:
#
# * one to predict the Annual Salary for Monthly/Salary employees;
# * another one to predict the Hourly Rate for Hourly employees;
#
# See ya!! 👋👋
#
# ----
#
# <br>
#
# <i>Previous Notebook:</i> <a href="https://www.kaggle.com/code/dsfelix/1-2-employees-annual-salary-in-chicago-analysis">1/2 - Employees' Annual Salary in Chicago Analysis</a>
